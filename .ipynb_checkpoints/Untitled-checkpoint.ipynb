# %%
import os
import rdflib
from copy import deepcopy
import argparse
import json
from typing import Union
from case_utils.namespace import *
import case_utils.ontology
from case_utils.ontology.version_info import CURRENT_CASE_VERSION
import importlib.resources


#NOTICE
# This software was produced for the U.S. Government under contract FA8702-22-C-0001,
# and is subject to the Rights in Data-General Clause 52.227-14, Alt. IV (DEC 2007)
# ©2022 The MITRE Corporation. All Rights Reserved.
# Released under PRS 18-4297.


__version__ = '0.0.2'

NS_SH = rdflib.SH
NS_RDF = rdflib.RDF
NS_XSD = rdflib.XSD

caseutils_version  = case_utils.__version__
#uco_version = '0.9.0' - don't know how uco denotes their version

ignore_keys = ['http://www.w3.org/2000/01/rdf-schema#range', #rdf:range
               'http://www.w3.org/2000/01/rdf-schema#label', #rdf:label
               'http://www.w3.org/2000/01/rdf-schema#comment', #rdf:comment
               'http://www.w3.org/ns/shacl#targetClass', #sh:targetClass
              ]

#direct uco vocabulary
# obs_prefix = {str(NS_UCO_OBSERVABLE):'observable:',
#               str(NS_UCO_CORE):'core:',
#               str(NS_UCO_TOOL):'tool:',
#               str(NS_UCO_ACTION):'action:',
#               str(NS_UCO_VOCABULARY):'vocabulary:',
#               str(NS_UCO_IDENTITY):'identity:',
#               str(NS_UCO_LOCATION):'location:',
#               str(NS_UCO_MARKING):'marking:',
#               str(NS_UCO_PATTERN):'pattern:',
#               str(NS_SH):'sh:',
#               str(NS_RDF):'rdfs:',
#               'http://www.w3.org/2000/01/rdf-schema#':'rdfs:',
#               str(NS_XSD):'xsd:',
#               str(NS_UCO_VICTIM):"victim:",
#               str(NS_UCO_ROLE):"role:",
#               str(NS_UCO_TYPES):"types:",
#              }

#case-uco vocabulary
obs_prefix = {  #uco vocabulary
                str(NS_UCO_MARKING):'uco-marking:',
                str(NS_UCO_TOOL):'uco-tool:',
                str(NS_SH):'sh:',
                str(NS_RDF):'rdfs:',
                str(NS_XSD):'xsd:',
                str(NS_RDF):'rdf:',
                str(NS_UCO_OBSERVABLE):'uco-observable:',
                str(NS_UCO_MARKING):'uco-marking:',
                str(NS_UCO_IDENTITY):'uco-identity:',
                str(NS_UCO_VICTIM):"uco-victim:",
                str(NS_UCO_VOCABULARY):'uco-vocabulary:',
                str(NS_UCO_PATTERN):'uco-pattern:',
                str(NS_UCO_CORE):'uco-core:',
                str(NS_UCO_TOOL):'uco-tool:',
                str(NS_UCO_ACTION):'uco-action:',
                str(NS_UCO_LOCATION):'uco-location:',
                'http://www.w3.org/2000/01/rdf-schema#':'rdfs:',
                str(NS_UCO_ROLE):"uco-role:",
                str(NS_UCO_TYPES):"uco-types:",
                #case vocab
                str(NS_CASE_INVESTIGATION): "investigation:",
                str(NS_CASE_VOCABULARY):'vocabulary:'}

reverse_obs_prefix = {}
for k,v in obs_prefix.items():
    reverse_obs_prefix[v] = k

def reducestring(string:str, returnChange=False):
    for k,v in obs_prefix.items():
        if k in string:
            if returnChange:
                return string.replace(k,v),True
            else:
                return string.replace(k,v)
    if returnChange:
        return str(string),False
    else:
        return str(string)


def makedirs(directory):
    os.makedirs(f'{directory}',exist_ok = True)

class main:
    def __init__(self,ontology_dir:str = None,directory:str = "templates", useCaseUtils:bool = False, short:bool = False ):
        makedirs(directory)

        self.switch = useCaseUtils
        if not ontology_dir:
            pass
        elif "," in ontology_dir:
            ontology_dir = ontology_dir.split(",")
        else:
            ontology_dir = [ontology_dir]
        self.generate_short = short
        self.onto_dir = ontology_dir
        self.prepad = "uco"
        if ontology_dir:
            self.files_dir = []
            for onto in ontology_dir:
                if os.path.isdir(onto):
                    for onto in self.onto_dir:
                        for root, dirs, files in os.walk(onto, topdown = False):
                           for name in files:
                               if name.endswith(".ttl"):
                                  adir = os.path.join(root, name)
                                  if adir not in self.files_dir:
                                      self.files_dir.append(adir)
                elif os.path.isfile(onto):
                  if adir not in self.files_dir:
                      self.files_dir.append(adir)
        self.directory = directory

    def paduco(self,string):
        v = string.split(":")[0]+":"
        if v in reverse_obs_prefix:
            return string #don't pad eg. investigation
        else:
            return self.prepad+"-"+string #if not defined, pad it.
    def removepad(self,string):
        if string.startswith(self.prepad):
            return string.replace(self.prepad + "-","")
        else:
            return string

    def load_graph(self):
        self.g = rdflib.Graph()
        if self.onto_dir:
            for file in self.files_dir:
                self.g.parse(file)
            if self.switch:
                case_utils.ontology.load_subclass_hierarchy(g)
        else:
            ttl_filename = "case-"+CURRENT_CASE_VERSION+".ttl"
            ttl_data = importlib.resources.read_text(case_utils.ontology, ttl_filename)
            self.g.parse(data=ttl_data)
            case_utils.ontology.load_subclass_hierarchy(self.g)
            
    def load_case_version(self):
        try:
            self.case_version = str([list(i) for i in self.g.query('SELECT ?s ?p ?o WHERE{?s owl:versionInfo ?o}')][0][2])
        except:
            self.case_version = CURRENT_CASE_VERSION
            

    def getSubClassOf(self,name:str):
        res = [i for i in self.g.query("SELECT ?o WHERE {{ {} rdfs:subClassOf ?o }}".format(name))]
        if res:
            return res[0]
        return res #comes back as list of triples
    
    def getProperty(self,name:str):
        res = [i for i in self.g.query("SELECT ?o WHERE {{ {} sh:property ?o }}".format(name))]
        return res #comes back as list of triples
    
    def getPath(self,name:str):
        res = [i for i in self.g.query("SELECT ?o WHERE {{ {} sh:path ?o }}".format(name))]
        return res #comes back as list of triples
    
    def getUCOname(self,name):
        return self.removepad(reducestring(name))
            
    def getParents(self,name:str,hist: list = [] ):
        parents = self.getSubClassOf(name)
        if not parents:
            return []
        else:
            for parent in parents: #DFS
                p = self.getUCOname(parent)
                if p not in hist:
                    hist.append(p)
                #check if each parent has parents that isn't part of hist
                for i in self.getParents(p,hist):
                    if i not in hist:
                        hist.append(i)
        return hist
            
    def generate_bnodes(self):
        self.bnode_dict = {}
        for triple in self.g.query("SELECT ?s ?o WHERE { ?s sh:property ?o}"):
            s, o = triple
            self.bnode_dict[str(s)] = []
            self.bnode_dict[str(s)].append(reducestring(o))
            
        for triple in self.g.query("SELECT ?s ?o WHERE { ?s sh:path ?o}"):
            s, o = triple
            if str(s) not in self.bnode_dict:
                self.bnode_dict[str(s)] = []
            self.bnode_dict[str(s)].append(reducestring(o))
            
    def generate_classes(self):
        self.class_names = []
        for triple in self.g.query("SELECT ?s ?p WHERE {?s ?p owl:Class}"):
            s, p = triple
            self.class_names.append(self.removepad(reducestring(s)))
        
    def findContext(self,dict_graph:dict):
        c = {}
        for t in dict_graph.keys():
            for k,v in obs_prefix.items():
                if self.paduco(t).startswith(self.paduco(v)):
                    c[v.strip(":")] = k.strip("/") + "#"
        return c
    
    def load_single(self,name:str):
        single = {'@context':{},
                  '@graph':[{}]
                 }
        single['@context']['kb'] = 'http://example.org/kb/'
        n = "".join(name.split(":")[1:])
        single['@graph'][0]['@id'] = "kb:"+n.lower()+"1"
        single['@graph'][0]['@type'] = self.paduco(name)
        
        #add the @type
        single['@context'].update(self.findContext({name:None}))
        
        #add the properties of the object
        props = self.getProperty(name)
        for prop in props:
            for p in self.bnode_dict[str(prop[0])]:
                if p:
                    single['@graph'][0][self.paduco(p)] = None
                    
        single['@context'].update(self.findContext(single['@graph'][0]))
            
        if self.generate_short:
            pass
        else:
            #add the parent's properties
            parents = self.getParents(name,[])
            for parent in parents:
                props = self.getProperty(parent)
                for prop in props:
                    for node in self.bnode_dict[str(prop[0])]:
                        single['@graph'][0][self.paduco(node)] = None

        return single
        

    def generate(self):
        self.load_graph()
        self.load_case_version()
        self.generate_bnodes()
        
        self.generate_classes()
        return


    def convertToJson(self,obj_name:str):
        vocab, newname = obj_name.split(":")
        
        obj = self.load_single(obj_name)
        
        if obj == {}:
            print(f"FAILED:{obj_name}")
            return
        nextdir = f"{self.directory}/{self.paduco(vocab)}"
        makedirs(nextdir)

        with open(f"{nextdir}/{newname}.json", 'w') as fl:
            json.dump(obj, fl,indent=2)
            fl.close()
        print(f"Success:{obj_name}")

    def run(self,name:Union[list,str] = None):
        if not name:
            name = self.class_names
        else:
            name = [name]
        for k in name:
            self.convertToJson(k)
        return

# %%
ontology = None
output = "test"
caseutil = False
short = False
specific = 'uco-observable:AndroidDevice'
obj = main(ontology,output,caseutil,short)
obj.generate()
#obj.load_single("observable:AndroidDevice")
#obj.run(specific)

# %%
obj.run("investigation:Authorization")
# Out:
# Success:investigation:Authorization

# %%
obj.run()
# Out:
# Success:investigation:Attorney
# Success:investigation:Authorization
# Success:investigation:Examiner
# Success:investigation:ExaminerActionLifecycle
# Success:investigation:Investigation
# Success:investigation:InvestigativeAction
# Success:investigation:Investigator
# Success:investigation:ProvenanceRecord
# Success:investigation:Subject
# Success:investigation:SubjectActionLifecycle
# Success:investigation:VictimActionLifecycle
# Success:action:Action
# Success:action:ActionArgumentFacet
# Success:action:ActionEstimationFacet
# Success:action:ActionFrequencyFacet
# Success:action:ActionLifecycle
# Success:action:ActionPattern
# Success:action:ArrayOfAction
# Success:core:Annotation
# Success:core:Assertion
# Success:core:AttributedName
# Success:core:Bundle
# Success:core:Compilation
# Success:core:ConfidenceFacet
# Success:core:ContextualCompilation
# Success:core:ControlledVocabulary
# Success:core:EnclosingCompilation
# Success:core:ExternalReference
# Success:core:Facet
# Success:core:Grouping
# Success:core:IdentityAbstraction
# Success:core:Item
# Success:core:MarkingDefinitionAbstraction
# Success:core:ModusOperandi
# Success:core:Relationship
# Success:core:UcoObject
# Success:identity:AddressFacet
# Success:identity:AffiliationFacet
# Success:identity:BirthInformationFacet
# Success:identity:CountryOfResidenceFacet
# Success:identity:EventsFacet
# Success:identity:IdentifierFacet
# Success:identity:Identity
# Success:identity:IdentityFacet
# Success:identity:LanguagesFacet
# Success:identity:NationalityFacet
# Success:identity:OccupationFacet
# Success:identity:Organization
# Success:identity:OrganizationDetailsFacet
# Success:identity:Person
# Success:identity:PersonalDetailsFacet
# Success:identity:PhysicalInfoFacet
# Success:identity:QualificationFacet
# Success:identity:RelatedIdentityFacet
# Success:identity:SimpleNameFacet
# Success:identity:VisaFacet
# Success:location:GPSCoordinatesFacet
# Success:location:LatLongCoordinatesFacet
# Success:location:Location
# Success:location:SimpleAddressFacet
# Success:marking:GranularMarking
# Success:marking:LicenseMarking
# Success:marking:MarkingDefinition
# Success:marking:MarkingModel
# Success:marking:ReleaseToMarking
# Success:marking:StatementMarking
# Success:marking:TermsOfUseMarking
# Success:observable:API
# Success:observable:ARPCache
# Success:observable:ARPCacheEntry
# Success:observable:Account
# Success:observable:AccountAuthenticationFacet
# Success:observable:AccountFacet
# Success:observable:Address
# Success:observable:AlternateDataStream
# Success:observable:AlternateDataStreamFacet
# Success:observable:AndroidDevice
# Success:observable:AndroidDeviceFacet
# Success:observable:Appliance
# Success:observable:Application
# Success:observable:ApplicationAccount
# Success:observable:ApplicationAccountFacet
# Success:observable:ApplicationFacet
# Success:observable:ArchiveFile
# Success:observable:ArchiveFileFacet
# Success:observable:Audio
# Success:observable:AudioFacet
# Success:observable:AutonomousSystem
# Success:observable:AutonomousSystemFacet
# Success:observable:BlockDeviceNode
# Success:observable:BluetoothAddress
# Success:observable:BluetoothAddressFacet
# Success:observable:BotConfiguration
# Success:observable:BrowserBookmark
# Success:observable:BrowserBookmarkFacet
# Success:observable:BrowserCookie
# Success:observable:BrowserCookieFacet
# Success:observable:Calendar
# Success:observable:CalendarEntry
# Success:observable:CalendarEntryFacet

# %%
obj.load_single("observable:AndroidDevice")
# Out:
# {'@context': {'kb': 'http://example.org/kb/'},
#  '@graph': [{'@id': 'kb:androiddevice1',
#    '@type': 'uco-observable:AndroidDevice',
#    'uco-observable:hasChanged': None,
#    'uco-observable:state': None,
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.load_single("observable:ObservableObject")
# Out:
# {'@context': {'kb': 'http://example.org/kb/',
#   'uco-observable': 'https://ontology.unifiedcyberontology.org/uco/observable#'},
#  '@graph': [{'@id': 'kb:observableobject1',
#    '@type': 'uco-observable:ObservableObject',
#    'uco-observable:hasChanged': None,
#    'uco-observable:state': None,
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.load_single("core:Item")
# Out:
# {'@context': {'kb': 'http://example.org/kb/'},
#  '@graph': [{'@id': 'kb:item1',
#    '@type': 'uco-core:Item',
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.load_single("core:UcoObject")
# Out:
# {'@context': {'kb': 'http://example.org/kb/',
#   'uco-core': 'https://ontology.unifiedcyberontology.org/uco/core#'},
#  '@graph': [{'@id': 'kb:ucoobject1',
#    '@type': 'uco-core:UcoObject',
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.load_single("investigation:Authorization")
# Out:
# {'@context': {'kb': 'http://example.org/kb/',
#   'investigation': 'https://ontology.caseontology.org/case/investigation#',
#   'uco-core': 'https://ontology.unifiedcyberontology.org/uco/core#'},
#  '@graph': [{'@id': 'kb:authorization1',
#    '@type': 'investigation:Authorization',
#    'uco-core:endTime': None,
#    'uco-core:startTime': None,
#    'investigation:authorizationType': None,
#    'investigation:authorizationIdentifier': None,
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.load_single("tool:DefensiveTool")
# Out:
# {'@context': {'kb': 'http://example.org/kb/'},
#  '@graph': [{'@id': 'kb:defensivetool1',
#    '@type': 'uco-tool:DefensiveTool',
#    'uco-tool:creator': None,
#    'uco-tool:references': None,
#    'uco-tool:servicePack': None,
#    'uco-tool:toolType': None,
#    'uco-tool:version': None,
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.load_single("investigation:Authorization")
# Out:
# {'@context': {'kb': 'http://example.org/kb/',
#   'investigation': 'https://ontology.caseontology.org/case/investigation#',
#   'uco-core': 'https://ontology.unifiedcyberontology.org/uco/core#'},
#  '@graph': [{'@id': 'kb:authorization1',
#    '@type': 'investigation:Authorization',
#    'uco-core:endTime': None,
#    'uco-core:startTime': None,
#    'investigation:authorizationType': None,
#    'investigation:authorizationIdentifier': None,
#    'uco-core:externalReference': None,
#    'uco-core:hasFacet': None,
#    'uco-core:createdBy': None,
#    'uco-core:objectMarking': None,
#    'uco-core:objectCreatedTime': None,
#    'uco-core:modifiedTime': None,
#    'uco-core:name': None,
#    'uco-core:specVersion': None,
#    'uco-core:description': None,
#    'uco-core:tag': None,
#    'uco-core:type': None,
#    'uco-core:id': None}]}

# %%
obj.bnode_dict
# Out:
# {'https://ontology.caseontology.org/case/investigation/Authorization': ['n50e56ee012ef4c6aa8ecdc58526c28cbb4'],
#  'https://ontology.caseontology.org/case/investigation/Investigation': ['n50e56ee012ef4c6aa8ecdc58526c28cbb10'],
#  'https://ontology.caseontology.org/case/investigation/InvestigativeAction': ['n50e56ee012ef4c6aa8ecdc58526c28cbb11'],
#  'https://ontology.caseontology.org/case/investigation/ProvenanceRecord': ['n50e56ee012ef4c6aa8ecdc58526c28cbb13'],
#  'https://ontology.unifiedcyberontology.org/uco/action/Action': ['n50e56ee012ef4c6aa8ecdc58526c28cbb35'],
#  'https://ontology.unifiedcyberontology.org/uco/action/ActionArgumentFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb41'],
#  'https://ontology.unifiedcyberontology.org/uco/action/ActionEstimationFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb45'],
#  'https://ontology.unifiedcyberontology.org/uco/action/ActionFrequencyFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb55'],
#  'https://ontology.unifiedcyberontology.org/uco/action/ActionLifecycle': ['n50e56ee012ef4c6aa8ecdc58526c28cbb65'],
#  'https://ontology.unifiedcyberontology.org/uco/action/ArrayOfAction': ['n50e56ee012ef4c6aa8ecdc58526c28cbb66'],
#  'https://ontology.unifiedcyberontology.org/uco/core/Annotation': ['n50e56ee012ef4c6aa8ecdc58526c28cbb73'],
#  'https://ontology.unifiedcyberontology.org/uco/core/Assertion': ['n50e56ee012ef4c6aa8ecdc58526c28cbb74'],
#  'https://ontology.unifiedcyberontology.org/uco/core/AttributedName': ['n50e56ee012ef4c6aa8ecdc58526c28cbb75'],
#  'https://ontology.unifiedcyberontology.org/uco/core/ConfidenceFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb76'],
#  'https://ontology.unifiedcyberontology.org/uco/core/ContextualCompilation': ['n50e56ee012ef4c6aa8ecdc58526c28cbb77'],
#  'https://ontology.unifiedcyberontology.org/uco/core/ControlledVocabulary': ['n50e56ee012ef4c6aa8ecdc58526c28cbb80'],
#  'https://ontology.unifiedcyberontology.org/uco/core/EnclosingCompilation': ['n50e56ee012ef4c6aa8ecdc58526c28cbb81'],
#  'https://ontology.unifiedcyberontology.org/uco/core/ExternalReference': ['n50e56ee012ef4c6aa8ecdc58526c28cbb84'],
#  'https://ontology.unifiedcyberontology.org/uco/core/Grouping': ['n50e56ee012ef4c6aa8ecdc58526c28cbb85'],
#  'https://ontology.unifiedcyberontology.org/uco/core/Relationship': ['n50e56ee012ef4c6aa8ecdc58526c28cbb91'],
#  'https://ontology.unifiedcyberontology.org/uco/core/UcoObject': ['n50e56ee012ef4c6aa8ecdc58526c28cbb103'],
#  'https://ontology.unifiedcyberontology.org/uco/identity/AddressFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb107'],
#  'https://ontology.unifiedcyberontology.org/uco/identity/BirthInformationFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb108'],
#  'https://ontology.unifiedcyberontology.org/uco/identity/SimpleNameFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb112'],
#  'https://ontology.unifiedcyberontology.org/uco/location/GPSCoordinatesFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb116'],
#  'https://ontology.unifiedcyberontology.org/uco/location/LatLongCoordinatesFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb119'],
#  'https://ontology.unifiedcyberontology.org/uco/location/SimpleAddressFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb125'],
#  'https://ontology.unifiedcyberontology.org/uco/marking/GranularMarking': ['n50e56ee012ef4c6aa8ecdc58526c28cbb127'],
#  'https://ontology.unifiedcyberontology.org/uco/marking/LicenseMarking': ['n50e56ee012ef4c6aa8ecdc58526c28cbb129'],
#  'https://ontology.unifiedcyberontology.org/uco/marking/MarkingDefinition': ['n50e56ee012ef4c6aa8ecdc58526c28cbb131'],
#  'https://ontology.unifiedcyberontology.org/uco/marking/ReleaseToMarking': ['n50e56ee012ef4c6aa8ecdc58526c28cbb133'],
#  'https://ontology.unifiedcyberontology.org/uco/marking/StatementMarking': ['n50e56ee012ef4c6aa8ecdc58526c28cbb135'],
#  'https://ontology.unifiedcyberontology.org/uco/marking/TermsOfUseMarking': ['n50e56ee012ef4c6aa8ecdc58526c28cbb137'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/AccountAuthenticationFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb140'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/AccountFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb154'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/AlternateDataStreamFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb161'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/AndroidDeviceFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb166'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ApplicationAccountFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb167'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ApplicationFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb171'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ArchiveFileFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb174'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/AudioFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb178'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/AutonomousSystemFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb181'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WhoIsFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb882'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/BluetoothAddressFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb186'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/BrowserBookmarkFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb193'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/BrowserCookieFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb201'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/CalendarEntryFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb216'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/CalendarFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb218'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/CallFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb226'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/CompressedStreamFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb228'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ComputerSpecificationFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb248'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactAddress': ['n50e56ee012ef4c6aa8ecdc58526c28cbb256'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactAffiliation': ['n50e56ee012ef4c6aa8ecdc58526c28cbb269'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactEmail': ['n50e56ee012ef4c6aa8ecdc58526c28cbb277'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb304'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactListFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb306'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactMessaging': ['n50e56ee012ef4c6aa8ecdc58526c28cbb308'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactPhone': ['n50e56ee012ef4c6aa8ecdc58526c28cbb316'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactProfile': ['n50e56ee012ef4c6aa8ecdc58526c28cbb322'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactSIP': ['n50e56ee012ef4c6aa8ecdc58526c28cbb330'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/ContactURL': ['n50e56ee012ef4c6aa8ecdc58526c28cbb342'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/
acet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb983'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryHiveFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb984'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryKeyFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb989'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryValue': ['n50e56ee012ef4c6aa8ecdc58526c28cbb992'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsServiceFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1000'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsTaskFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1069'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsThreadFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1083'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WindowsVolumeFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1092'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/WirelessNetworkConnectionFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1105'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/X509CertificateFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1125'],
#  'https://ontology.unifiedcyberontology.org/uco/observable/X509V3ExtensionsFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1141'],
#  'https://ontology.unifiedcyberontology.org/uco/pattern/LogicalPattern': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1205'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/BuildConfigurationType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1207'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/BuildFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1208'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/BuildInformationType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1219'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/BuildUtilityType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1222'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/CompilerType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1225'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/ConfigurationSettingType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1229'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/DependencyType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1231'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/LibraryType': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1233'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/Tool': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1238'],
#  'https://ontology.unifiedcyberontology.org/uco/tool/ToolConfigurationTypeFacet': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1240'],
#  'https://ontology.unifiedcyberontology.org/uco/types/ControlledDictionary': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1241'],
#  'https://ontology.unifiedcyberontology.org/uco/types/ControlledDictionaryEntry': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1243'],
#  'https://ontology.unifiedcyberontology.org/uco/types/Dictionary': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1244'],
#  'https://ontology.unifiedcyberontology.org/uco/types/DictionaryEntry': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1246'],
#  'https://ontology.unifiedcyberontology.org/uco/types/Hash': ['n50e56ee012ef4c6aa8ecdc58526c28cbb1254'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1': ['uco-core:endTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb6': ['uco-core:endTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb89': ['uco-core:endTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb2': ['uco-core:startTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb7': ['uco-core:startTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb90': ['uco-core:startTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb3': ['investigation:authorizationType'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb4': ['investigation:authorizationIdentifier'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb5': ['investigation:relevantAuthorization'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb8': ['investigation:investigationStatus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb9': ['investigation:focus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb10': ['investigation:investigationForm'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb11': ['investigation:wasInformedBy'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb12': ['investigation:exhibitNumber'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb13': ['investigation:rootExhibitNumber'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb17': ['uco-action:subaction'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb18': ['uco-action:environment'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb19': ['uco-action:performer'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb20': ['uco-action:error'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb61': ['uco-action:error'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb21': ['uco-action:instrument'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb22': ['uco-action:object'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb23': ['uco-action:participant'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb24': ['uco-action:result'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb25': ['uco-action:location'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb26': ['uco-action:endTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb62': ['uco-action:endTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb27': ['uco-action:startTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb63': ['uco-action:startTime'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb28': ['uco-action:actionCount'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb64': ['uco-action:actionCount'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb29': ['uco-action:actionStatus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb30': ['uco-action:actionStatus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb35': ['uco-action:actionStatus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb65': ['uco-action:actionStatus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb40': ['uco-action:argumentName'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb41': ['uco-action:value'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb42': ['uco-action:estimatedCost'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb43': ['uco-action:estimatedEfficacy'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb44': ['uco-action:estimatedImpact'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb45': ['uco-action:objective'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb46': ['uco-action:rate'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb47': ['uco-action:scale'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb48': ['uco-action:units'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb49': ['uco-action:trend'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cb
],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb944': ['uco-observable:loaderFlags'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb945': ['uco-observable:numberOfRVAAndSizes'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb946': ['uco-observable:sectionAlignment'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb947': ['uco-observable:sizeOfCode'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb948': ['uco-observable:sizeOfHeaders'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb949': ['uco-observable:sizeOfHeapCommit'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb950': ['uco-observable:sizeOfHeapReserve'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb951': ['uco-observable:sizeOfImage'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb952': ['uco-observable:sizeOfInitializedData'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb953': ['uco-observable:sizeOfStackCommit'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb954': ['uco-observable:sizeOfStackReserve'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb955': ['uco-observable:sizeOfUninitializedData'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb956': ['uco-observable:win32VersionValue'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb957': ['uco-observable:dllCharacteristics'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb958': ['uco-observable:magic'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb959': ['uco-observable:majorImageVersion'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb960': ['uco-observable:majorOSVersion'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb961': ['uco-observable:majorSubsystemVersion'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb962': ['uco-observable:minorImageVersion'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb963': ['uco-observable:minorOSVersion'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb964': ['uco-observable:minorSubsystemVersion'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb965': ['uco-observable:subsystem'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb970': ['uco-observable:volume'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb971': ['uco-observable:accessedDirectory'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb972': ['uco-observable:accessedFile'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb973': ['uco-observable:firstRun'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb974': ['uco-observable:lastRun'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb975': ['uco-observable:timesExecuted'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb976': ['uco-observable:applicationFileName'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb977': ['uco-observable:prefetchHash'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb978': ['uco-observable:startupInfo'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb979': ['uco-observable:aslrEnabled'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb980': ['uco-observable:depEnabled'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb981': ['uco-observable:ownerSID'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb983': ['uco-observable:windowTitle'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb984': ['uco-observable:hiveType'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb985': ['uco-observable:creator'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb986': ['uco-observable:registryValues'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb988': ['uco-observable:numberOfSubkeys'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb989': ['uco-observable:key'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb991': ['uco-observable:data'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb992': ['uco-observable:dataType'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb993': ['uco-observable:serviceName'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb995': ['uco-observable:groupName'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb996': ['uco-observable:serviceStatus'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb997': ['uco-observable:serviceType'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb998': ['uco-observable:startCommandLine'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb999': ['uco-observable:startType'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1000': ['uco-observable:descriptions'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1020': ['uco-observable:account'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1022': ['uco-observable:workItemData'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1023': ['uco-observable:workingDirectory'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1024': ['uco-observable:actionList'],
#  'n50e56ee012ef4c6aa8ecdc58526c28cbb1025': ['uco-observable:triggerList'],
#  ...}

# %%
[i for i in obj.g.query("SELECT ?s WHERE {?s ?p owl:Class}")]
# Out:
# [(rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/Attorney'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/Authorization'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/Examiner'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/ExaminerActionLifecycle'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/Investigation'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/InvestigativeAction'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/Investigator'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/ProvenanceRecord'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/Subject'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/SubjectActionLifecycle'),),
#  (rdflib.term.URIRef('https://ontology.caseontology.org/case/investigation/VictimActionLifecycle'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/Action'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/ActionArgumentFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/ActionEstimationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/ActionFrequencyFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/ActionLifecycle'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/ActionPattern'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/action/ArrayOfAction'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Annotation'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Assertion'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/AttributedName'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Bundle'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Compilation'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/ConfidenceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/ContextualCompilation'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/ControlledVocabulary'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/EnclosingCompilation'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/ExternalReference'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Facet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Grouping'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/IdentityAbstraction'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Item'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/MarkingDefinitionAbstraction'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/ModusOperandi'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/Relationship'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/core/UcoObject'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/AddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/AffiliationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/BirthInformationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/CountryOfResidenceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/EventsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/IdentifierFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/Identity'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/IdentityFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/LanguagesFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/NationalityFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/OccupationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/Organization'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/OrganizationDetailsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/Person'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/PersonalDetailsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/PhysicalInfoFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/QualificationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/RelatedIdentityFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/SimpleNameFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/identity/VisaFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/location/GPSCoordinatesFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/location/LatLongCoordinatesFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/location/Location'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/location/SimpleAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/GranularMarking'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/LicenseMarking'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/MarkingDefinition'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/MarkingModel'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/ReleaseToMarking'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/StatementMarking'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/marking/TermsOfUseMarking'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/API'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ARPCache'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ARPCacheEntry'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Account'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AccountAuthenticationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Address'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AlternateDataStream'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AlternateDataStreamFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AndroidDevice'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AndroidDeviceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Appliance'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Application'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ApplicationAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ApplicationAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ApplicationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ArchiveFile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ArchiveFileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Audio'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AudioFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AutonomousSystem'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/AutonomousSystemFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BlockDeviceNode'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BluetoothAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BluetoothAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BotConfiguration'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BrowserBookmark'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BrowserBookmarkFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BrowserCookie'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/BrowserCookieFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Calendar'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CalendarEntry'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CalendarEntryFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CalendarFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Call'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CallFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CharacterDeviceNode'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Code'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CompressedStreamFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ComputerSpecification'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ComputerSpecificationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Contact'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactAffiliation'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactEmail'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactList'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactListFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactMessaging'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactPhone'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactProfile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactSIP'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContactURL'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContentData'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ContentDataFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CookieHistory'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Credential'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/CredentialDump'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DNSCache'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DNSRecord'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DataRangeFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DefinedEffectFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Device'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DeviceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DigitalAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DigitalAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DigitalAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DigitalAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DigitalSignatureInfo'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DigitalSignatureInfoFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Directory'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Disk'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DiskFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DiskPartition'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DiskPartitionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DomainName'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/DomainNameFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EXIFFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EmailAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EmailAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EmailAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EmailAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EmailMessage'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EmailMessageFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EncodedStreamFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EncryptedStreamFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EnvironmentVariable'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Event'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EventFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/EventLog'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ExtInodeFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ExtractedString'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ExtractedStringsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/File'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/FileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/FilePermissionsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/FileSystem'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/FileSystemFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/FileSystemObject'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ForumPost'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ForumPrivateMessage'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/FragmentFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GUI'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GenericObservableObject'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GeoLocationEntry'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GeoLocationEntryFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GeoLocationLog'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GeoLocationLogFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GeoLocationTrack'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GeoLocationTrackFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/GlobalFlagType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/HTTPConnection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/HTTPConnectionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Hostname'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ICMPConnection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ICMPConnectionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IComHandlerActionType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IExecActionType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPNetmask'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPv4Address'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPv4AddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPv6Address'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IPv6AddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/IShowMessageActionType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Image'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ImageFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/InstantMessagingAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/InstantMessagingAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Junction'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Library'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/LibraryFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MACAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MACAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Memory'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MemoryFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Message'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MessageFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MessageThread'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MessageThreadFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MftRecordFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MimePartType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MobileAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MobileAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MobileDevice'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MobileDeviceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Mutex'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/MutexFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NTFSFile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NTFSFileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NTFSFilePermissionsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NamedPipe'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkAppliance'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkConnection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkConnectionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkFlow'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkFlowFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkInterface'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkInterfaceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkProtocol'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkRoute'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NetworkSubnet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Note'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/NoteFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Observable'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ObservableAction'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ObservableObject'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ObservablePattern'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ObservableRelationship'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Observation'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/OnlineService'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/OnlineServiceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/OperatingSystem'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/OperatingSystemFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PDFFile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PDFFileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PathRelationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PaymentCard'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PhoneAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PhoneAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Pipe'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Post'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Process'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ProcessFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Profile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ProfileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PropertiesEnumeratedEffectFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/PropertyReadEffectFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/RasterPicture'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/RasterPictureFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ReparsePoint'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SIMCard'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SIMCardFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SIPAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SIPAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SMSMessage'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SMSMessageFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SQLiteBlob'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SQLiteBlobFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SecurityAppliance'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Semaphore'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SendControlCodeEffectFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ShopListing'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Snapshot'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Socket'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SocketAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Software'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SoftwareFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/StateChangeEffectFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SymbolicLink'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/SymbolicLinkFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/TCPConnection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/TCPConnectionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/TaskActionType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Thread'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/TriggerType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Tweet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/TwitterProfileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXFile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXFilePermissionsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXProcess'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXProcessFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UNIXVolumeFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URL'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URLFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URLHistory'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URLHistoryEntry'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URLHistoryFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URLVisit'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/URLVisitFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UserAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UserAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UserSession'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/UserSessionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/ValuesEnumeratedEffectFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Volume'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/VolumeFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WebPage'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WhoIs'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WhoIsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WhoisContactFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WhoisRegistrarInfoType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WifiAddress'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WifiAddressFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/Wiki'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WikiArticle'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsActiveDirectoryAccount'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsActiveDirectoryAccountFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsComputerSpecification'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsComputerSpecificationFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsCriticalSection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsEvent'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsFilemapping'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsHandle'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsHook'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsMailslot'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsNetworkShare'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPEBinaryFile'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPEBinaryFileFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPEFileHeader'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPEOptionalHeader'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPESection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPrefetch'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsPrefetchFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsProcess'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsProcessFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryHive'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryHiveFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryKey'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryKeyFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsRegistryValue'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsService'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsServiceFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsSystemRestore'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsTask'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsTaskFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsThread'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsThreadFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsVolumeFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WindowsWaitableTime'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WirelessNetworkConnection'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/WirelessNetworkConnectionFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/X509Certificate'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/X509CertificateFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/X509V3Certificate'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/observable/X509V3ExtensionsFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/pattern/LogicalPattern'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/pattern/Pattern'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/pattern/PatternExpression'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/role/BenevolentRole'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/role/MaliciousRole'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/role/NeutralRole'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/role/Role'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/AnalyticTool'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/BuildConfigurationType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/BuildFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/BuildInformationType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/BuildUtilityType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/CompilerType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/ConfigurationSettingType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/DefensiveTool'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/DependencyType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/LibraryType'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/MaliciousTool'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/Tool'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/tool/ToolConfigurationTypeFacet'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/types/ControlledDictionary'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/types/ControlledDictionaryEntry'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/types/Dictionary'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/types/DictionaryEntry'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/types/Hash'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/victim/Victim'),),
#  (rdflib.term.URIRef('https://ontology.unifiedcyberontology.org/uco/victim/VictimTargeting'),)]
